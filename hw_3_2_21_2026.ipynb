# %% [markdown]
# ## Dictionaries!  Modeling the World with Structure
# In class I talked about how dictionaries are more computationally efficient, but I think there's something more intuitive, less computery here when we talk about the difference between lists and dictionaries.
# I think it comes down to the fact that lists help us store sequences.
# But, dictionaries help us model relationships. What do I mean by that?
#
# In global affairs, or econ, or poly sci, data is rarely just a list. It’s a set of relationships. Some examples:
#
# A country : its population
# A vote : its outcome
# A policy area : its funding level
# A state : its risk score
#
# That mapping relationship is what dictionaries can best capture and render.

# %% [markdown]
# ### Dictionaries: Let's Review
# A dictionary stores key:value pairs.

# %%
country = {
    "name": "Kenya",
    "region": "East Africa",
    "population_millions": 56
}

# %% [markdown]
# Here:
#
# "name" is the key
# "Kenya" is the value
# "region" is another key, with the value "East Africa"
# "population_millions" is the key, 56 the value. You get it.
#
# One thing to note is that there can be many keys, but they must be unique. Let me explain that a little better.
#
# Why dictionaries are designed this way
#
# Because dictionaries are built for fast lookup:
#
# “Given this key, give me the value"
#
# #### A dictionary is a mapping: each key points to exactly one value.
#
# So this is allowed:

# %%
country = {
    "name": "Kenya",
    "population": 56
}

# %% [markdown]
# Here, "name" maps to "Kenya", and "population" maps to 56.
#
# #### But you cannot have two separate entries with the same key that both “co-exist” in the dictionary. If you try, Python will keep only one.
#
# What happens if you repeat a key?

# %%
country = {
    "name": "Kenya",
    "name": "Brazil"
}
print(country)
# Out:
# {'name': 'Brazil'}

# %% [markdown]
# Result: the dictionary ends up as:

# %%
{'name': 'Brazil'}
# Out:
# {'name': 'Brazil'}

# %% [markdown]
# #### The second "name" overwrites the first. Python doesn’t store both. It just updates the value for that key. *
#
# A helpful mental model:
#
# A dictionary is like a labeling system.
#
# If you put two labels with the same name on the same drawer, the “later label” replaces what you meant earlier.
#
# #### Why dictionaries are designed this way
#
# Because dictionaries are built for fast lookup:
#
# “Given this key, give me the value.”
#
# If the same key could have multiple values, then country["name"] would be ambiguous:
#
# Which one should it return?
#
# So Python enforces the idea: one key maps to one current value. Make sense?

# %% [markdown]
# #### Creating a dictionary
#
#
# country = {
#     "name": "Kenya",
#     "region": "East Africa",
#     "population_millions": 56
# }

# %% [markdown]
# Read this out loud:
#
# The key "name" maps to the value "Kenya"
# The key "region" maps to the value "East Africa"
#
# This is called a key : value pair.
#
# Notice the Syntax
#
# Curly braces { } define a dictionary.
#
# Keys and values are separated by a colon :
#
# Each pair is separated by a comma ,
#
# If you forget a comma, Python will complain.
#
# If you forget a colon, Python will complain.
#
# Dictionaries are strict about structure.

# %% [markdown]
# #### Accessing Values
#
# To retrieve information from a dictionary, you use the key:

# %%
print(country["name"])
# Out:
# Brazil

# %% [markdown]
# Above, you are telling Python:
#
# “Given this key, return its value.”

# %% [markdown]
# ####

# %% [markdown]
# #### Unique Keys
# Run this:

# %%
test = {
    "name": "Kenya",
    "name": "Brazil"
}

print(test)
# Out:
# {'name': 'Brazil'}

# %% [markdown]
# Before running it, predict the output.
#
# Now run it.
#
# What happened?
#
# Python did not store both values. The second "name" overwrote the first.
#
# Why?
#
# Because a dictionary is a mapping system.
#
# It answers:
#
# “Given this key, what is its value?”
#
# If one key had multiple different values stored separately, the lookup would be ambiguous.
#
# So Python enforces:
#
# Each key must be unique.
# One key has one current value.

# %%
#We use index with lists or strings, but not with dictionaries!
#DON'T DO THIS: 
print(country[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[197], line 3
#       1 #We use index with lists or strings, but not with dictionaries!
#       2 #DON'T DO THIS:
# ----> 3 print(country[0])
#
# KeyError: 0

# %% [markdown]
# Why does this fail?
#
# Because dictionaries are not ordered collections accessed by position.
#
# Lists use positions.
# Dictionaries use keys.
#
# This is a structural difference, not just a syntax difference.

# %% [markdown]
# ### Modifying Dictionaries
# Dictionaries are mutable.
#
# You can add a new key like this:

# %%
country["capital"] = "Nairobi"

# %%
You can update an existing key like this:
# Out:
#   Cell In[9], line 1
#     You can update an existing key like this:
#         ^
# SyntaxError: invalid syntax

# %%
country["population_millions"] = 57

# %% [markdown]
# If the key exists then update.
# If the key does not exist then create.

# %% [markdown]
# ### Dangerous Bug
# Run this:

# %%
country["populaton_millons"} = 60
print(country)
# Out:
#   Cell In[11], line 1
#     country["populaton_millons"} = 60
#                                ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %% [markdown]
# Notice the missing “i” in "population".
#
# Did Python give you an error?
#
# No.
#
# It created a new key.
#
# ##### This is one of the most dangerous beginner dictionary bugs:
#
# **SILENT BUT DEADLY!  Silent typos create new keys instead of errors!**

# %% [markdown]
# ### Looping Through Dictionaries
# As we discussed in class, when you loop over a dicitionary, by degault, Python gives us the keys.

# %%
country = {
    "name": "Kenya",
    "region": "East Africa",
    "population_millions": 57,
    "capital": "Nairobi"
}

for item in country:
    print(item)
# Out:
# name
# region
# population_millions
# capital

# %% [markdown]
# What prints?
#
# Only the keys.
#
# Why?
#
# Because the dictionary’s primary identity is its key structure.

# %% [markdown]
# ### Accessing Values While Looping
#
# If you want the values too, you must explicitly retrieve them.

# %%
for key in country:
    print(key, ":", country[key])
# Out:
# name : Kenya
# region : East Africa
# population_millions : 57
# capital : Nairobi

# %% [markdown]
# Here’s what’s happening:
#
# The loop gives you a key
#
# You use that key to look up its value
#
# This pattern is extremely common.

# %% [markdown]
# ### Another way of accessing values:

# %%
un_votes = {
    "USA": "Yes",
    "China": "No",
    "France": "Yes",
    "Brazil": "Abstain"
}

for vote in un_votes.values():
    print(vote)
# Out:
# Yes
# No
# Yes
# Abstain

# %% [markdown]
# ### Using .items to access key, value pairs
# If you want both key and value automatically:

# %%
for key, value in country.items():
    print(key, ":", value)
# Out:
# name : Kenya
# region : East Africa
# population_millions : 57
# capital : Nairobi

# %% [markdown]
# .items() returns pairs.
#
# This is the cleanest pattern for dictionary analysis.

# %% [markdown]
# ### COMMON MISTAKE:
# Students, and (even profs :-) sometimes forget the proper way and try to do this:

# %%
for key, value in country:
    print(key, value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for key, value in country:
#       2     print(key, value)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# This fails.
#
# Why?
# The error reads:ValueError: too many values to unpack (expected 2)
# Because looping over a dictionary alone does not return two things. It returns only the key.
#
# Python cannot unpack one value into two variables.

# %% [markdown]
# ### Exercises:

# %%
un_votes = {
    "USA": "Yes",
    "China": "No",
    "France": "Yes",
    "Brazil": "Abstain"
}

# %% [markdown]
# 1. Print only the country names

# %%
#Your code here:
for country in un_votes:
    print(country)
# Out:
# USA
# China
# France
# Brazil

# %%
2. Write code that returns:
USA voted Yes
China voted No

# %%
#Your code here:
for key, value in un_votes.items():
    print(key, "voted", value)
    if key == "China":
        break
# Out:
# USA voted Yes
# China voted No

# %% [markdown]
# 3. Let's count how many countries voted "Yes." Show me two ways (two different for loops)!

# %%
#3a.
total_yes = 0

#Your code here:
for country in un_votes:
    total_yes += un_votes[country].count("Yes")

print(total_yes)
# Out:
# 2

# %%
#3b.
yes_count = 0

for vote in un_votes.values():
    total_yes += value.count("Yes")

print(total_yes)
# Out:
# 2

# %% [markdown]
# 4. Let's count multiple categories
# Count:
#
# Yes
#
# No
#
# Abstain
#
# Here is some code to debug. This student didn't do it quite right. Give them a hand!

# %%
yes_count = 0
no_count = 0
abstain_count = 0

for country, vote in un_votes.items():
    if vote == "Yes":
        yes_count += 1
    if vote == "No":
        no_count += 1
    if vote == "Abstain":
        abstain_count += 1

print(yes_count)
print(no_count)
print(abstain_count)
# Out:
# 2
# 1
# 1

# %% [markdown]
# 5. Aid budget in millions

# %%
aid_budget = {
    "health": 120,
    "education": 80,
    "defense": 200,
    "infrastructure": 150
}

# %% [markdown]
# 5a. Print each Category and Allocation (hint.... .items())

# %%
#Your code here:
for category, allocation in aid_budget.items():
    print(category, ":", allocation)
# Out:
# health : 120
# education : 80
# defense : 200
# infrastructure : 150

# %% [markdown]
# 5b. Compute the Total Allocation (hint, create a total variable = 0 before the loop. Think .values()

# %%
#Your code here:
Total_allocation = 0

for category, allocation in aid_budget.items():
    Total_allocation += allocation

print(Total_allocation)
# Out:
# 550

# %% [markdown]
# 5c Determine the Largest Allocation. (Track the largest value seen so far, and trace which category it belongs to). Let me show you how you'd do that

# %%
#Your code here:
max_category = None
max_value = 0


for category, allocation in aid_budget.items():
    if allocation > max_value:
        max_value = allocation
        max_category = category

print("Largest allocation:", max_category, "with", max_value)
# Out:
# Largest allocation: defense with 200

# %% [markdown]
# Explain in sentences how this works:
#
# 1) Create two empty variable for max_category and max_value
# 2) The for loop goes through each category and allocation
#       The first allocation value when compare with max_value will always be greater (because all the values are positive)
# 3) the first value will pass the if-statement: max_value will now take on the first allocation value
# 4) Since the first value pass the if-statement: max_category will now take on the category correspond to that allocation
# 5) The for loop pass through each category and allocation, for allocation values greater than the current one, they will pass the if statement
#     Once passing the if statement, the max_value and max_category will take on the new allocation and category

# %%
6. We can also use max() to get the largest value!
# Out:
#   Cell In[50], line 1
#     6. We can also use max() to get the largest value!
#        ^
# SyntaxError: invalid syntax

# %%
largest_value = max(aid_budget.values())
print("Largest allocation:", largest_value)
# Out:
# Largest allocation: 200

# %% [markdown]
# Explain why

# %%
max(aid_budget)
# Out:
# 'infrastructure'

# %% [markdown]
# 7. returns what it does: your sentence here:
#
# Python applies "max" to dictionary keys by default. Because python compares string alphabetically when using max and i is after d,e, and h. Therefore max(aid_budget) outputs the alphabetically largest key.

# %% [markdown]
# ### Nested Dictionaries
# When we work in real world data we often have many countries, categories, numbers. This is where each value in a dictionary is itself a dictionary!! For example:

# %%
aid_by_country = {
    "Kenya": {
        "health": 40,
        "education": 25,
        "infrastructure": 30
    },
    "Brazil": {
        "health": 35,
        "education": 20,
        "infrastructure": 15
    },
    "Chile": {
        "health": 55,
        "education": 10,
        "infrastructure": 45
    }
}

# %% [markdown]
# aid_by_country["Kenya"] gives Kenya’s budget dictionary
#
# aid_by_country["Kenya"]["health"] gives Kenya’s health allocation
#
# So we are doing:
#
# Outer lookup : get the country dictionary
#
# Inner lookup : get the category value

# %% [markdown]
# 8. Print Chile’s infrastructure allocation

# %%
#Your code here:
aid_by_country["Chile"]["infrastructure"]
# Out:
# 45

# %% [markdown]
# 9. Print Brazil's education allocation:

# %%
#Your code here:
aid_by_country["Brazil"]["education"]
# Out:
# 20

# %% [markdown]
# 10. Print all the country names:

# %%
#Your code here:
for country in aid_by_country: 
    print(country)
# Out:
# Kenya
# Brazil
# Chile

# %% [markdown]
# 11. Print Each Country’s Health Spending

# %%
#Your code here:
for country, spending in aid_by_country.items(): 
    print(country, ":", spending["health"])
# Out:
# Kenya : 40
# Brazil : 35
# Chile : 55

# %% [markdown]
# 12. Print All Categories for Each Country in this structure:
#
# Kenya
#   health = 40
#   education = 25
#   infrastructure = 30
# Brazil
#   health = 35
#   education = 20
#   infrastructure = 15
# Chile
#   health = 55
#   education = 10
#   infrastructure = 45

# %%
#Your code here:
for country, spending in aid_by_country.items(): 
    print(country)
    print("health =", spending["health"])
    print("education =", spending["education"])
    print("infrastructure =", spending["infrastructure"])
# Out:
# Kenya
# health = 40
# education = 25
# infrastructure = 30
# Brazil
# health = 35
# education = 20
# infrastructure = 15
# Chile
# health = 55
# education = 10
# infrastructure = 45

# %% [markdown]
# 13. Print Only Education Values (no country names)

# %%
# Your code here:

for spending in aid_by_country.values(): 
    print(spending["education"])
# Out:
# 25
# 20
# 10

# %% [markdown]
# 14. Write code that prints only those Countries Where Health > 40

# %%
#Your code here:
for country, spending in aid_by_country.items(): 
    if spending["health"] > 40: 
        print(country)
# Out:
# Chile

# %% [markdown]
# 15. Print Health + Education Together (hint: add health and education values and total them)

# %%
#Your code here:
health_educ = 0 

for spending in aid_by_country.values(): 
    health_educ += spending["health"] + spending["education"]

print(health_educ)
# Out:
# 185

# %% [markdown]
# 16. Compute Total Aid Per Country

# %%
#Your code here:
total_aid_Kenya = 0
total_aid_Brazil = 0
total_aid_Chile = 0

for country, spending in aid_by_country.items(): 
    if country == "Kenya":
        total_aid_Kenya = spending["health"] + spending["education"] + spending["infrastructure"]
    if country == "Brazil":
        total_aid_Brazil = spending["health"] + spending["education"] + spending["infrastructure"]
    if country == "Chile":
        total_aid_Chile = spending["health"] + spending["education"] + spending["infrastructure"]

print(total_aid_Kenya)
print(total_aid_Brazil)
print(total_aid_Chile)
# Out:
# 95
# 70
# 110

# %% [markdown]
# 17. Add a New Category and Recompute Totals
# Add a new key/value pair for each country:
#
# "governance": 5 (for Kenya)
#
# "governance": 10 (for Brazil)
#
# "governance": 0 (for Chile)

# %%
aid_by_country["Kenya"]["governance"] = "5"
aid_by_country["Brazil"]["governance"] = "10"
aid_by_country["Chile"]["governance"] = "0"

print(aid_by_country)
# Out:
# {'Kenya': {'health': 40, 'education': 25, 'infrastructure': 30, 'governance': '5'}, 'Brazil': {'health': 35, 'education': 20, 'infrastructure': 15, 'governance': '10'}, 'Chile': {'health': 55, 'education': 10, 'infrastructure': 45, 'governance': '0'}}

# %% [markdown]
# 18. We don't always have complete data when we collect country data. Look at this data dictionary. Sometimes data looks like the data below when you pull it from an API:

# %%
global_aid_data = {
    "Kenya": {
        "region": "East Africa",
        "income_level": "Lower Middle Income",
        "aid": {
            "health": 40,
            "education": 25,
            "infrastructure": 30,
            "governance": 5
        }
    },
    "Brazil": {
        "region": "South America",
        "income_level": "Upper Middle Income",
        "aid": {
            "health": 35,
            "education": 20,
            "infrastructure": 15,
            "governance": 10
        }
    },
    "Chile": {
        "region": "South America",
        "income_level": "High Income",
        "aid": {
            "health": 55,
            "education": 10,
            "infrastructure": 45
        }
    },
    "Haiti": {
        "region": "Caribbean",
        "income_level": "Low Income",
        "aid": {
            "health": 20,
            "infrastructure": 10
        }
    },
    "Ukraine": {
        "region": "Eastern Europe",
        "income_level": None,
        "aid": {
            "health": 70,
            "education": 30,
            "infrastructure": 80,
            "governance": None
        }
    },
    "Nepal": {
        "region": "South Asia",
        "aid": {
            "health": 25,
            "education": 15
        }
    },
    "Nigeria": {
        "region": "West Africa",
        "income_level": "Lower Middle Income",
        "aid": {
            "health": 50,
            "infrastructure": None,
            "governance": 8
        }
    },
    "Germany": {
        "region": "Western Europe",
        "income_level": "High Income",
        "aid": {}
    },
    "Afghanistan": {
        "region": "South Asia",
        "income_level": "Low Income"
    },
    "Peru": {
        "income_level": "Upper Middle Income",
        "aid": {
            "health": 22,
            "education": 18,
            "infrastructure": 12
        }
    },
    "India": {
        "region": "South Asia",
        "income_level": "Lower Middle Income",
        "aid": {
            "health": 60,
            "education": 45,
            "governance": 12
        }
    },
    "Canada": {
        "region": "North America",
        "income_level": "High Income",
        "aid": None
    },
    "Ethiopia": {
        "region": "East Africa",
        "income_level": "Low Income",
        "aid": {
            "health": 38,
            "education": None,
            "infrastructure": 25
        }
    },
    "Indonesia": {
        "region": "Southeast Asia",
        "aid": {
            "health": 33,
            "education": 28,
            "infrastructure": 40,
            "governance": 6
        }
    },
    "France": {
        "region": "Western Europe",
        "income_level": "High Income"
    },
    "Colombia": {
        "region": "South America",
        "income_level": "Upper Middle Income",
        "aid": {
            "health": 29
        }
    },
    "Somalia": {
        "region": None,
        "income_level": "Low Income",
        "aid": {
            "health": 18,
            "education": 9,
            "governance": None
        }
    },
    "Vietnam": {
        "region": "Southeast Asia",
        "income_level": "Lower Middle Income",
        "aid": {
            "education": 26,
            "infrastructure": 35
        }
    }
}

# %% [markdown]
# Your challenge is to create a uniform schema for this data dictionary, and decide how you want to treat missing or incomplete data. At the end of your data cleaning exercise, You should have a uniform scheuma and a print of missing values for each country and category. What's the best way? You decide!

# %%
#your code here:
Country = []
Second_level = set()
Third_level = set()
Total_second_key = 0

for country, country_info in global_aid_data.items():
    Country.append(country)
    for second_key, second_value in country_info.items():
        Second_level.add(second_key)
        # Only loop if this value is a dictionary
        if isinstance(second_value, dict):
            for third_key in second_value.keys():
                Third_level.add(third_key)


for country, country_info in global_aid_data.items():       
    missing_keys = Second_level - country_info.keys()
    for key in missing_keys:
        if key == "aid":
            country_info[key] = {}       
        elif key == "region":
            country_info[key] = None     
        elif key == "income_level":
            country_info[key] = None  
    
for country, country_info in global_aid_data.items():       
    aid_dict = country_info.get("aid") 
    if isinstance(aid_dict, dict):
        missing_aid = Third_level - aid_dict.keys()
        for key in missing_aid:
            aid_dict[key] = 0   
        country_info["aid"] = aid_dict  #
    else:
        country_info["aid"] = {key: 0 for key in Third_level}


for country, info in global_aid_data.items(): 
    print(country)
    print("region =", info["region"])
    print("income_level =", info["income_level"])
    print("aid =", info["aid"])
# Out:
# Kenya
# region = East Africa
# income_level = Lower Middle Income
# aid = {'health': 40, 'education': 25, 'infrastructure': 30, 'governance': 5}
# Brazil
# region = South America
# income_level = Upper Middle Income
# aid = {'health': 35, 'education': 20, 'infrastructure': 15, 'governance': 10}
# Chile
# region = South America
# income_level = High Income
# aid = {'health': 55, 'education': 10, 'infrastructure': 45, 'governance': 0}
# Haiti
# region = Caribbean
# income_level = Low Income
# aid = {'health': 20, 'infrastructure': 10, 'education': 0, 'governance': 0}
# Ukraine
# region = Eastern Europe
# income_level = None
# aid = {'health': 70, 'education': 30, 'infrastructure': 80, 'governance': None}
# Nepal
# region = South Asia
# income_level = None
# aid = {'health': 25, 'education': 15, 'infrastructure': 0, 'governance': 0}
# Nigeria
# region = West Africa
# income_level = Lower Middle Income
# aid = {'health': 50, 'infrastructure': None, 'governance': 8, 'education': 0}
# Germany
# region = Western Europe
# income_level = High Income
# aid = {'education': 0, 'health': 0, 'infrastructure': 0, 'governance': 0}
# Afghanistan
# region = South Asia
# income_level = Low Income
# aid = {'education': 0, 'health': 0, 'infrastructure': 0, 'governance': 0}
# Peru
# region = None
# income_level = Upper Middle Income
# aid = {'health': 22, 'education': 18, 'infrastructure': 12, 'governance': 0}
# India
# region = South Asia
# income_level = Lower Middle Income
# aid = {'health': 60, 'education': 45, 'governance': 12, 'infrastructure': 0}
# Canada
# region = North America
# income_level = High Income
# aid = {'education': 0, 'health': 0, 'infrastructure': 0, 'governance': 0}
# Ethiopia
# region = East Africa
# income_level = Low Income
# aid = {'health': 38, 'education': None, 'infrastructure': 25, 'governance': 0}
# Indonesia
# region = Southeast Asia
# income_level = None
# aid = {'health': 33, 'education': 28, 'infrastructure': 40, 'governance': 6}
# France
# region = Western Europe
# income_level = High Income
# aid = {'education': 0, 'health': 0, 'infrastructure': 0, 'governance': 0}
# Colombia
# region = South America
# income_level = Upper Middle Income
# aid = {'health': 29, 'education': 0, 'infrastructure': 0, 'governance': 0}
# Somalia
# region = None
# income_level = Low Income
# aid = {'health': 18, 'education': 9, 'governance': None, 'infrastructure': 0}
# Vietnam
# region = Southeast Asia
# income_level = Lower Middle Income
# aid = {'education': 26, 'infrastructure': 35, 'health': 0, 'governance': 0}

# %% [markdown]
# 19. Below are some voter donation records.

# %%
voter_data = {
    "V001": {
        "age": 52,
        "profession": "Attorney",
        "party_affiliation": "Republican",
        "annual_income": 240000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 5000, "Joe Biden": 0}
    },
    "V002": {
        "age": 34,
        "profession": "Software Engineer",
        "party_affiliation": "Independent",
        "annual_income": 180000,
        "favorite_tv_station": "CNN",
        "donations": {"Donald Trump": 1500}
    },
    "V003": {
        "age": 61,
        "profession": "Real Estate Developer",
        "party_affiliation": "Republican",
        "annual_income": 420000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 12000}
    },
    "V004": {
        "age": 45,
        "profession": "Doctor",
        "party_affiliation": "Democrat",
        "annual_income": 310000,
        "favorite_tv_station": "MSNBC",
        "donations": {"Joe Biden": 7000}
    },
    "V005": {
        "age": 29,
        "profession": "Consultant",
        "party_affiliation": "Republican",
        "annual_income": 150000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 3000}
    },
    "V006": {
        "age": 50,
        "profession": "Business Owner",
        "party_affiliation": "Republican",
        "annual_income": 350000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 8000}
    },
    "V007": {
        "age": 41,
        "profession": "Teacher",
        "party_affiliation": "Democrat",
        "annual_income": 68000,
        "favorite_tv_station": "CNN",
        "donations": {}
    },
    "V008": {
        "age": 38,
        "profession": "Investment Banker",
        "party_affiliation": "Republican",
        "annual_income": 500000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 20000}
    },
    "V009": {
        "age": 47,
        "profession": "Engineer",
        "party_affiliation": "Independent",
        "annual_income": 130000,
        "favorite_tv_station": None,
        "donations": {"Donald Trump": 2500}
    },
    "V010": {
        "age": 56,
        "profession": "Retired",
        "party_affiliation": "Republican",
        "annual_income": 90000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 4000}
    },
    "V011": {
        "age": 33,
        "profession": "Entrepreneur",
        "party_affiliation": "Republican",
        "annual_income": 270000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 9500}
    },
    "V012": {
        "age": 44,
        "profession": "Professor",
        "party_affiliation": "Democrat",
        "annual_income": 120000,
        "favorite_tv_station": "PBS",
        "donations": {"Joe Biden": 3000}
    },
    "V013": {
        "age": 39,
        "profession": None,
        "party_affiliation": "Republican",
        "annual_income": 110000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 1200}
    },
    "V014": {
        "age": 62,
        "profession": "Executive",
        "party_affiliation": "Republican",
        "annual_income": 600000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 25000}
    },
    "V015": {
        "age": 27,
        "profession": "Analyst",
        "party_affiliation": "Independent",
        "annual_income": 95000,
        "favorite_tv_station": "CNN",
        "donations": {"Donald Trump": 800}
    },
    "V016": {
        "age": 49,
        "profession": "Real Estate Developer",
        "party_affiliation": "Republican",
        "annual_income": 390000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 15000}
    },
    "V017": {
        "age": 58,
        "profession": "Business Owner",
        "party_affiliation": "Republican",
        "annual_income": 310000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 7000}
    },
    "V018": {
        "age": 36,
        "profession": "Lawyer",
        "party_affiliation": "Democrat",
        "annual_income": 210000,
        "favorite_tv_station": "CNN",
        "donations": {"Joe Biden": 5000}
    },
    "V019": {
        "age": 53,
        "profession": "Investor",
        "party_affiliation": "Republican",
        "annual_income": 450000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 18000}
    },
    "V020": {
        "age": 40,
        "profession": "Engineer",
        "party_affiliation": "Republican",
        "annual_income": 160000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 3500}
    },
    "V021": {
        "age": 46,
        "profession": "Consultant",
        "party_affiliation": None,
        "annual_income": 200000,
        "favorite_tv_station": "CNN",
        "donations": {"Donald Trump": 2200}
    },
    "V022": {
        "age": 37,
        "profession": "Doctor",
        "party_affiliation": "Republican",
        "annual_income": 280000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 6000}
    },
    "V023": {
        "age": 60,
        "profession": "Executive",
        "party_affiliation": "Republican",
        "annual_income": 720000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 30000}
    },
    "V024": {
        "age": 42,
        "profession": "Entrepreneur",
        "party_affiliation": "Independent",
        "annual_income": 320000,
        "favorite_tv_station": "Bloomberg",
        "donations": {"Donald Trump": 5000}
    },
    "V025": {
        "age": 31,
        "profession": "Analyst",
        "party_affiliation": "Democrat",
        "annual_income": 85000,
        "favorite_tv_station": "CNN",
        "donations": {}
    },
    "V026": {
        "age": 55,
        "profession": "Business Owner",
        "party_affiliation": "Republican",
        "annual_income": 410000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 11000}
    },
    "V027": {
        "age": 48,
        "profession": "Investment Banker",
        "party_affiliation": "Republican",
        "annual_income": 550000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 22000}
    },
    "V028": {
        "age": 35,
        "profession": "Engineer",
        "party_affiliation": "Independent",
        "annual_income": 140000,
        "favorite_tv_station": "CNN",
        "donations": {"Donald Trump": 900}
    },
    "V029": {
        "age": 63,
        "profession": "Retired",
        "party_affiliation": "Republican",
        "annual_income": 95000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 4500}
    },
    "V030": {
        "age": 44,
        "profession": "Consultant",
        "party_affiliation": "Republican",
        "annual_income": 210000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 5200}
    },
    "V031": {
        "age": 38,
        "profession": "Attorney",
        "party_affiliation": "Republican",
        "annual_income": 260000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 6800}
    },
    "V032": {
        "age": 29,
        "profession": "Entrepreneur",
        "party_affiliation": "Republican",
        "annual_income": 195000,
        "favorite_tv_station": None,
        "donations": {"Donald Trump": 2500}
    },
    "V033": {
        "age": 51,
        "profession": "Investor",
        "party_affiliation": "Republican",
        "annual_income": 480000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 16000}
    },
    "V034": {
        "age": 46,
        "profession": "Executive",
        "party_affiliation": "Republican",
        "annual_income": 650000,
        "favorite_tv_station": "Fox Business",
        "donations": {"Donald Trump": 27000}
    },
    "V035": {
        "age": 54,
        "profession": "Engineer",
        "party_affiliation": "Republican",
        "annual_income": 175000,
        "favorite_tv_station": "Fox News",
        "donations": {"Donald Trump": 3100}
    }
    
}

# %% [markdown]
#  Determine the top three biggest donors to Donald Trump’s campaign, and report their profession and donation amount.

# %%
max_person = None
max_donation = 0
second_max_donation = 0 
second_max_person = None
third_max_donation = 0 
third_max_person = None

for voter_id, values in voter_data.items():
    trump_donation = voter_data.get(voter_id, {}).get("donations", {}).get("Donald Trump", 0)
    if trump_donation > max_donation:
        
        # push down the previous max values
        third_max_donation = second_max_donation
        third_max_person = second_max_person
        
        second_max_donation = max_donation
        second_max_person = max_person

        max_donation = trump_donation
        max_person = voter_id


    elif trump_donation < max_donation and trump_donation > second_max_donation:
        # push down previous second max
        third_max_donation = second_max_donation
        third_max_person = second_max_person
        
        second_max_donation = trump_donation
        second_max_person = voter_id
        
    elif trump_donation < second_max_donation and trump_donation > third_max_donation:
        third_max_donation = trump_donation
        third_max_person = voter_id
        
        
print("Top 3 Donald Trump donors:")
print(max_person, max_donation, voter_data.get(voter_id, {}).get("profession", {}))
print(second_max_person, second_max_donation, voter_data.get(voter_id, {}).get("profession", {}))
print(third_max_person, third_max_donation, voter_data.get(voter_id, {}).get("profession", {}))
# Out:
# Top 3 Donald Trump donors:
# V023 30000 Executive
# V034 27000 Executive
# V014 25000 Executive

# %% [markdown]
# 20. Please give me a link to your chat log here:

# %% [markdown]
# https://chatgpt.com/share/69a0f613-53b8-8007-8e7c-42f255c42928
